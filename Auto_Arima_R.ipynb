# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyaram-k/Beer_sales_prediction/blob/main/Auto_Arima_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if(!require('forecast')) {
  install.packages('forecast')
  library('forecast')
}
# Out:
# Loading required package: forecast
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘forecast’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘quadprog’, ‘quantmod’, ‘fracdiff’, ‘lmtest’, ‘Rcpp’, ‘timeDate’, ‘tseries’, ‘urca’, ‘zoo’, ‘RcppArmadillo’
#
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
data = read.csv('https://raw.githubusercontent.com/Satyaram-k/Beer_sales_prediction/main/BeerDataSet.csv')

# %%
head(data)
# Out:
#   Month   Monthly.beer.production
# 1 1956-01 93.2
# 2 1956-02 96.0
# 3 1956-03 95.2
# 4 1956-04 77.1
# 5 1956-05 70.9
# 6 1956-06 64.8

# %%
auto.arima(data[,2], trace=TRUE)
# Out:
#  Fitting models using approximations to speed things up...
#
#  ARIMA(2,1,2) with drift         : 4053.591
#  ARIMA(0,1,0) with drift         : 4174.408
#  ARIMA(1,1,0) with drift         : 4151.972
#  ARIMA(0,1,1) with drift         : 4140.673
#  ARIMA(0,1,0)                    : 4172.41
#  ARIMA(1,1,2) with drift         : 4060.051
#  ARIMA(2,1,1) with drift         : 4059.879
#  ARIMA(3,1,2) with drift         : 4054.286
#  ARIMA(2,1,3) with drift         : 4055.189
#  ARIMA(1,1,1) with drift         : 4058.853
#  ARIMA(1,1,3) with drift         : 4062.009
#  ARIMA(3,1,1) with drift         : 4063.415
#  ARIMA(3,1,3) with drift         : Inf
#  ARIMA(2,1,2)                    : 4054.368
#
#  Now re-fitting the best model(s) without approximations...
#
#  ARIMA(2,1,2) with drift         : 4057.628
#
#  Best model: ARIMA(2,1,2) with drift
# Series: data[, 2]
# ARIMA(2,1,2) with drift
#
# Coefficients:
#           ar1     ar2      ma1      ma2   drift
# ...

# %%
fit <- auto.arima(data[,2])
plot(forecast(fit))
# Out:
# Plot with title “Forecasts from ARIMA(2,1,2) with drift”
